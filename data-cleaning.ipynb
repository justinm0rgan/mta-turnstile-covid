# %% [markdown]
# # MTA Traffic Forecasting
# Khyatee Desai & Justin Morgan
# ## Part 2: Data Cleaning
# This notebook includes the data cleaning process

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Import Data
# Concatenate each data file into a Pandas dataframe

# %%
df = pd.read_csv("./data/turnstile_210313.txt")
df
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  03/06/2021
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  03/06/2021
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  03/06/2021
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  03/06/2021
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  03/06/2021
# ...       ...   ...       ...            ...      ...      ...         ...
# 209312  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  03/12/2021
# 209313  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  03/12/2021
# 209314  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  03/12/2021
# 209315  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  03/12/2021
# 209316  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  03/12/2021
#
#             TIME     DESC  ENTRIES  \
# 0       03:00:00  REGULAR  7540642
# 1       07:00:00  REGULAR  7540645
# 2       11:00:00  REGULAR  7540676
# 3       15:00:00  REGULAR  7540764
# 4       19:00:00  REGULAR  7540904
# ...          ...      ...      ...
# 209312  04:00:00  REGULAR     5554
# 209313  08:00:00  REGULAR     5554
# 209314  12:00:00  REGULAR     5554
# 209315  16:00:00  REGULAR     5554
# 209316  20:00:00  REGULAR     5554
#
#         EXITS
# 0                                                 2572027
# 1                                                 2572030
# 2                                                 2572093
# 3                                                 2572128
# 4                                                 2572160
# ...                                                   ...
# 209312                                                544
# 209313                                                544
# 209314                                                544
# 209315                                                544
# 209316                                                544
#
# [209317 rows x 11 columns]
